# %%
"""This module should contain Python code.

Install the tvdatafeed package from a terminal instead:

pip install --upgrade --no-cache-dir git+https://github.com/rongardF/tvdatafeed.git
"""

# %%
from tvDatafeed import TvDatafeed, Interval

# username = 'YourTradingViewUsername'
# password = 'YourTradingViewPassword'

tv = TvDatafeed()
# Out:
# you are using nologin method, data you access may be limited

# %%
# index
bitcoin_data = tv.get_hist(symbol='BANKNIFTY1!',exchange='NSE',interval=Interval.in_1_hour,n_bars=1000)

# # futures continuous contract
# nifty_futures_data = tv.get_hist(symbol='NIFTY',exchange='NSE',interval=Interval.in_1_hour,n_bars=1000,fut_contract=1)

# # crudeoil
# crudeoil_data = tv.get_hist(symbol='CRUDEOIL',exchange='MCX',interval=Interval.in_1_hour,n_bars=5000,fut_contract=1)

# # downloading data for extended market hours
# extended_price_data = tv.get_hist(symbol="EICHERMOT",exchange="NSE",interval=Interval.in_1_hour,n_bars=500, extended_session=False)

# %%
bitcoin_data
# Out:
#                               symbol     open     high      low    close  \
# datetime
# 2025-09-25 05:45:00  NSE:BANKNIFTY1!  55310.0  55348.4  55175.0  55208.0
# 2025-09-25 06:45:00  NSE:BANKNIFTY1!  55206.0  55439.0  55200.0  55374.6
# 2025-09-25 07:45:00  NSE:BANKNIFTY1!  55389.0  55426.4  55321.4  55360.0
# 2025-09-25 08:45:00  NSE:BANKNIFTY1!  55360.0  55375.0  55102.0  55130.0
# 2025-09-25 09:45:00  NSE:BANKNIFTY1!  55133.2  55165.0  55086.0  55094.6
# ...                              ...      ...      ...      ...      ...
# 2026-04-28 05:45:00  NSE:BANKNIFTY1!  55965.0  55965.0  55630.0  55670.0
# 2026-04-28 06:45:00  NSE:BANKNIFTY1!  55676.0  55750.0  55589.0  55646.2
# 2026-04-28 07:45:00  NSE:BANKNIFTY1!  55646.2  55724.8  55490.2  55515.0
# 2026-04-28 08:45:00  NSE:BANKNIFTY1!  55525.0  55629.0  55400.0  55414.8
# 2026-04-28 09:45:00  NSE:BANKNIFTY1!  55417.6  55423.8  55376.0  55397.6
#
#                        volume
# datetime
# 2025-09-25 05:45:00   91000.0
# ...

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 25.0 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 24.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 35.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 33.8 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
bitcoin_data['close'].rolling(20).mean().tail(20).plot(kind='line')
# Out:
# <Axes: xlabel='datetime'>

# %%
bitcoin_data['close'].rolling(20).mean().plot(kind='line')
# Out:
# <Axes: xlabel='datetime'>
